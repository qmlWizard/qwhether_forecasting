# %%
from src.models.qnn import QNN
from pennylane import numpy as np

# %%
x = np.asarray([0.2, 0.3, 0.4])
model = QNN(n_qubits=3, n_layers=3, n_features=3, device_name='default.qubit')

# %%
model.forward(x)
# Out:
# tensor([0.6260, 0.6495, 0.0303], dtype=torch.float64, grad_fn=<StackBackward0>)

# %%
import torch
import pennylane as qml

print("PyTorch:", torch.__version__)
print("PennyLane:", qml.__version__)
# Out:
# PyTorch: 2.13.0+cu130
# PennyLane: 0.45.1
