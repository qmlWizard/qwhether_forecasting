# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
## APPL STOCKS DATA

data = yf.download(
    "AAPL",
    start="2015-01-01",
    end="2025-01-01",
    interval="1d",
    auto_adjust=True
)

monthly_avg = (
    data['Close']['AAPL']
    .resample('ME')
    .mean()
)

numpy_data = monthly_avg.reset_index()['AAPL'].to_numpy()
np.save('aapl_stock_monthly.npy', numpy_data)

plt.plot(numpy_data)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
## Delhi Tempreture Data

df_train = pd.read_csv('DailyDelhiClimateTrain.csv')
df_test = pd.read_csv('DailyDelhiClimateTest.csv')
df_train = pd.concat([df_train, df_test])
df = df_train.reset_index()['meantemp'].to_numpy()
np.save('daily_temp_delhi.npy', df)

# %%
import pandas as pd
df = pd.read_csv('indian_nifty50_stocks_10y_daily.csv')

# %%
df['Ticker'].unique()
# Out:
# <StringArray>
# [  'ADANIENT.NS', 'ADANIPORTS.NS', 'APOLLOHOSP.NS', 'ASIANPAINT.NS',
#    'AXISBANK.NS', 'BAJAJ-AUTO.NS', 'BAJAJFINSV.NS', 'BAJFINANCE.NS',
#         'BEL.NS', 'BHARTIARTL.NS',      'CIPLA.NS',  'COALINDIA.NS',
#     'DRREDDY.NS',  'EICHERMOT.NS',     'GRASIM.NS',    'HCLTECH.NS',
#    'HDFCBANK.NS',   'HINDALCO.NS', 'HINDUNILVR.NS',  'ICICIBANK.NS',
#      'INDIGO.NS',       'INFY.NS',        'ITC.NS',   'JSWSTEEL.NS',
#   'KOTAKBANK.NS',         'LT.NS',        'M&M.NS',     'MARUTI.NS',
#   'NESTLEIND.NS',       'NTPC.NS',       'ONGC.NS',  'POWERGRID.NS',
#    'RELIANCE.NS',       'SBIN.NS', 'SHRIRAMFIN.NS',  'SUNPHARMA.NS',
#  'TATACONSUM.NS',  'TATASTEEL.NS',        'TCS.NS',      'TECHM.NS',
#       'TITAN.NS',      'TRENT.NS', 'ULTRACEMCO.NS',      'WIPRO.NS']
# Length: 44, dtype: str

# %%
import numpy as np
df_nifty = df[df['Ticker'] == 'INFY.NS'].dropna().reset_index()
nifty = df_nifty['Close'].to_numpy()
np.save('nifty_l10y.npy', nifty)
